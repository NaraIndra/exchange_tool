# %%
import pandas as pd

# %%
first_data = pd.read_csv('bm_rates_new.csv', usecols=[0, 1, 2, 3, 4, 5, 8],
            names=[
                "cur_give_id",
                "cur_take_id",
                "saler_id",
                "amount_give",
                "amount_take",
                "volume",
                "datetime",
            ])

# %%
first_data.describe()
# Out:
#          cur_give_id    cur_take_id       saler_id   amount_give  \
# count  177039.000000  177039.000000  177039.000000  1.770390e+05
# mean      104.577602     100.620733     656.004197  2.322750e+04
# std        51.941421      51.853948     241.506561  3.708208e+05
# min         1.000000       1.000000       1.000000  1.000000e+00
# 25%        60.000000      58.000000     517.000000  1.000000e+00
# 50%       105.000000      95.000000     633.000000  1.014810e+00
# 75%       148.000000     141.000000     896.000000  4.322040e+01
# max       198.000000     198.000000     980.000000  4.788707e+07
#
#         amount_take        volume
# count  1.770390e+05  1.770390e+05
# mean   2.983569e+04  1.069637e+07
# std    6.609954e+05  4.432956e+07
# min    1.000000e+00  0.000000e+00
# 25%    1.000000e+00  1.300432e+04
# 50%    1.000000e+00  2.172540e+05
# 75%    7.432662e+01  2.045712e+06
# max    1.000000e+08  1.193600e+09

# %%
first_data.head()
# Out:
#    cur_give_id  cur_take_id  saler_id  amount_give  amount_take    volume  \
# 0          163           63       614          1.0      76.9166  14203.16
# 1           41           63       614          1.0      88.1275  14203.16
# 2          120           63       614          1.0      89.7696  14203.16
# 3          140           63       614          1.0    5212.1656  14203.16
# 4          129           63       614          1.0      75.2001  14203.16
#
#                      datetime
# 0  2020-10-20 15:44:01.385359
# 1  2020-10-20 15:44:01.385359
# 2  2020-10-20 15:44:01.385359
# 3  2020-10-20 15:44:01.385359
# 4  2020-10-20 15:44:01.385359

# %%
first_data
# Out:
#         cur_give_id  cur_take_id  saler_id  amount_give  amount_take  \
# 0               163           63       614         1.00      76.9166
# 1                41           63       614         1.00      88.1275
# 2               120           63       614         1.00      89.7696
# 3               140           63       614         1.00    5212.1656
# 4               129           63       614         1.00      75.2001
# ...             ...          ...       ...          ...          ...
# 177034           96            1       104         1.00       6.0500
# 177035            1           56       104         1.00      22.5000
# 177036            1            3       104         1.29       1.0000
# 177037            1            2       104         1.00      68.0000
# 177038            1           96       104        13.00       1.0000
#
#           volume                    datetime
# 0       14203.16  2020-10-20 15:44:01.385359
# 1       14203.16  2020-10-20 15:44:01.385359
# ...

# %%
second_data = pd.read_csv('bm_rates_new.csv',  usecols=[0, 1, 2, 3, 4, 5, 8],
            names=[
                "cur_give_id",
                "cur_take_id",
                "saler_id",
                "amount_give",
                "amount_take",
                "volume",
                "datetime",
            ])

# %%
second_data
# Out:
#         cur_give_id  cur_take_id  saler_id  amount_give  amount_take  \
# 0               163           63       614         1.00      76.9166
# 1                41           63       614         1.00      88.1275
# 2               120           63       614         1.00      89.7696
# 3               140           63       614         1.00    5212.1656
# 4               129           63       614         1.00      75.2001
# ...             ...          ...       ...          ...          ...
# 177034           96            1       104         1.00       6.0500
# 177035            1           56       104         1.00      22.5000
# 177036            1            3       104         1.29       1.0000
# 177037            1            2       104         1.00      68.0000
# 177038            1           96       104        13.00       1.0000
#
#           volume                    datetime
# 0       14203.16  2020-10-20 15:44:01.385359
# 1       14203.16  2020-10-20 15:44:01.385359
# ...

# %%
frames = [first_data, second_data]

# %%
res = pd.concat(frames)

# %%
res
# Out:
#         cur_give_id  cur_take_id  saler_id  amount_give  amount_take  \
# 0               163           63       614         1.00      76.9166
# 1                41           63       614         1.00      88.1275
# 2               120           63       614         1.00      89.7696
# 3               140           63       614         1.00    5212.1656
# 4               129           63       614         1.00      75.2001
# ...             ...          ...       ...          ...          ...
# 177034           96            1       104         1.00       6.0500
# 177035            1           56       104         1.00      22.5000
# 177036            1            3       104         1.29       1.0000
# 177037            1            2       104         1.00      68.0000
# 177038            1           96       104        13.00       1.0000
#
#           volume                    datetime
# 0       14203.16  2020-10-20 15:44:01.385359
# 1       14203.16  2020-10-20 15:44:01.385359
# ...

# %%
min_date = res.datetime.min()

# %%
min_date
# Out:
# '2020-10-20 15:44:01.385359'

# %%
res.drop(res[res.datetime == min_date].index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9d655ec3e338> in <module>
# ----> 1 res.drop(res[res.datetime == min_date].index, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
res

# %%
db = pd.read_csv('db_pairs_sec.csv',  usecols=[0, 1, 2, 3, 4, 5, 8],
            names=[
                "cur_give_id",
                "cur_take_id",
                "saler_id",
                "amount_give",
                "amount_take",
                "volume",
                "datetime",
            ])
# Out:
# /home/ikira/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (1,2,3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
db
# Out:
#         cur_give_id  cur_take_id     saler_id  amount_give  amount_take  \
# 0               NaN  cur_give_id  cur_take_id     saler_id  amount_give
# 1               0.0          NaN  cur_give_id  cur_take_id     saler_id
# 2               1.0          0.0          NaN  cur_give_id  cur_take_id
# 3               2.0          1.0          0.0            6           59
# 4               3.0          2.0          1.0          121           49
# ...             ...          ...          ...          ...          ...
# 704040     176017.0           96            1          104            1
# 704041     176018.0            1           56          104            1
# 704042     176019.0            1            3          104         1.29
# 704043     176020.0            1            2          104            1
# 704044     176021.0            1           96          104           13
#
#              volume datetime
# 0       amount_take      NaN
# 1       amount_give      NaN
# ...

# %%
new = pd.read_csv('bm_rates_new.csv',  usecols=[0, 1, 2, 3, 4, 5, 8],
            names=[
                "cur_give_id",
                "cur_take_id",
                "saler_id",
                "amount_give",
                "amount_take",
                "volume",
                "datetime",
            ])

# %%
new
# Out:
#         cur_give_id  cur_take_id  saler_id  amount_give   amount_take  \
# 0               149           59       619         1.00   8715.284595
# 1                19          181       184         1.00     27.932961
# 2               149          124       798         1.00  26676.486984
# 3                99          141       689         1.00     38.443232
# 4                99          141       689         1.00     38.443232
# ...             ...          ...       ...          ...           ...
# 176765           96            1       104         1.00      6.050000
# 176766            1           56       104         1.00     22.500000
# 176767            1            3       104         1.29      1.000000
# 176768            1            2       104         1.00     68.000000
# 176769            1           96       104        13.00      1.000000
#
#               volume                    datetime
# 0       1.134660e+03  2020-10-20 16:31:45.383316
# ...

# %%
frames = [db, new]

# %%
ass = pd.concat(frames)

# %%
ass
# Out:
#         cur_give_id  cur_take_id     saler_id  amount_give  amount_take  \
# 0               NaN  cur_give_id  cur_take_id     saler_id  amount_give
# 1               0.0          NaN  cur_give_id  cur_take_id     saler_id
# 2               1.0          0.0          NaN  cur_give_id  cur_take_id
# 3               2.0          1.0          0.0            6           59
# 4               3.0          2.0          1.0          121           49
# ...             ...          ...          ...          ...          ...
# 176765         96.0            1          104            1         6.05
# 176766          1.0           56          104            1         22.5
# 176767          1.0            3          104         1.29            1
# 176768          1.0            2          104            1           68
# 176769          1.0           96          104           13            1
#
#              volume                    datetime
# 0       amount_take                         NaN
# ...
